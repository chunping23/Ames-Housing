# %% [markdown]
# # House Prices: Advanced Regression Techniques
#
# Aim of this project is to predict the house price based on various features
#
# Dataset to downloaded from the below link
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# All the Lifecycle In A Data Science Projects
# 1. Exploratory Data Analysis (EDA)
# 2. Feature Engineering
# 3. Feature Selection
# 4. Model Building
# 5. Model Deployment
#
# # Exploratory Data Analysis:

# %%
#import the require libraries 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
## Display all the columns of the dataframe

pd.pandas.set_option('display.max_columns',None)

# %%
train = pd.read_csv("train.csv")
print(train.shape)
# Out:
# (1460, 81)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# In Data Analysis We will Analyze To Find out the below stuff
# 1. Missing Values
# 2. All The Numerical Variables
# 3. Distribution of the Numerical Variables
# 4. Categorical Variables
# 5. Cardinality of Categorical Variables
# 6. Outliers
# 7. Relationship between independent and dependent feature(SalePrice)

# %% [markdown]
# # Missing Values

# %%
# Check the Percentage of the missing values and sort it in descending order

#Step 1 Make the list of features that has missing values
features_with_na = [features for features in train.columns if train[features].isnull().sum() >1]

#Step 2 Lets code the feature name and the percentage of missing values

for feature in features_with_na:
    
    print(feature, np.round(train[feature].isnull().mean(), 4), '% Missing values')
# Out:
# LotFrontage 0.1774 % Missing values
# Alley 0.9377 % Missing values
# MasVnrType 0.0055 % Missing values
# MasVnrArea 0.0055 % Missing values
# BsmtQual 0.0253 % Missing values
# BsmtCond 0.0253 % Missing values
# BsmtExposure 0.026 % Missing values
# BsmtFinType1 0.0253 % Missing values
# BsmtFinType2 0.026 % Missing values
# FireplaceQu 0.4726 % Missing values
# GarageType 0.0555 % Missing values
# GarageYrBlt 0.0555 % Missing values
# GarageFinish 0.0555 % Missing values
# GarageQual 0.0555 % Missing values
# GarageCond 0.0555 % Missing values
# PoolQC 0.9952 % Missing values
# Fence 0.8075 % Missing values
# MiscFeature 0.963 % Missing values

# %% [markdown]
# # Since there are many missing values, we need to find the relationship between missing values and Sales Price
#
# Let's Plot some Diagram for this relationships

# %%
for feature in features_with_na:
    data = train.copy()
    
    # Lets make a variable that indicate 1 if the observation was missing or zero otherwise
    data[feature] = np.where(data[feature].isnull(), 1, 0)
    
    # Lets calculate the mean SalePrice where the information is missing or present
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# Here With the relation between the missing values and the dependent variable is clearly visible.So We need to replace these nan values with something meaningful which we will do in the Feature Engineering section
#
# From the above dataset some of the features like Id is not required

# %%
print('Id of Houses {}'.format(len(train.Id)))
# Out:
# Id of Houses 1460

# %% [markdown]
# # Numerical Variables

# %%
# list of numerical variables
numerical_features = [feature for feature in train.columns if train[feature].dtypes != 'O']

print('Number of Numerical Variables: ',len(numerical_features))
# Out:
# Number of Numerical Variables:  38

# %%
train[numerical_features].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# #### Temporal Variables(Eg: Datetime Variables)
#
# From the Dataset we have 4 year variables. We have extract information from the datetime variables like no of years or no of days. One example in this specific scenario can be difference in years between the year the house was built and the year the house was sold. We will be performing this analysis in the Feature Engineering Later.

# %%
# list of variables that contain year information
year_feature = [feature for feature in train[numerical_features] if 'Yr' in feature or 'Year' in feature]

year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# let's explore the content of these year variables
for feature in year_feature:
    print(feature,train[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
## Lets analyze the Temporal Datetime Variables
## We will check whether there is a relation between year the house is sold and the sales price

train.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Sale price')
plt.title('Relationship between Year Sold vs Sales Price')
# Out:
# Text(0.5, 1.0, 'Relationship between Year Sold vs Sales Price')

# %%
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# Lets now plot the other 3 Year feature with sales price except for YrSold
 
for feature in year_feature:
    if feature!='YrSold':
        data=train.copy()
        ## We will capture the difference between year variable and year the house was sold for
        data[feature]=data['YrSold']-data[feature]

        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %%
## Numerical variables are usually of 2 type
## 1. Continous variable and Discrete Variables

discrete_feature=[feature for feature in numerical_features if len(train[feature].unique())<25 and feature not in year_feature+['Id']]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 17

# %%
discrete_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
train[discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
## Lets Find the realtionship between them and SalePrice

for feature in discrete_feature:
    data=train.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Sale Price')
    plt.title(feature)
    plt.show()

# %% [markdown]
# Conclusion: There's a relationship between the above data variable and the sale price

# %% [markdown]
# #### Continuous Variable

# %%
continuous_feature=[feature for feature in numerical_features if feature not in discrete_feature+year_feature+['Id']]
print("Continuous feature Count {}".format(len(continuous_feature)))
# Out:
# Continuous feature Count 16

# %%
# Let's analyse the continuous values by creating histograms to understand the distribution

for feature in continuous_feature:
    data=train.copy()
    train[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.title(feature)
    plt.show()

# %% [markdown]
# # logarithmic transformation
#
# Lets use Logarithmic Transformation to transform the data.

# %%
## We will be using logarithmic transformation


for feature in continuous_feature:
    data=train.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data['SalePrice']=np.log(data['SalePrice'])
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalesPrice')
        plt.title(feature)
        plt.show()

# %% [markdown]
# ### Outliners

# %%
# We can use box-Plot to identify Outliners

for feature in continuous_feature:
    data= train.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# #### Categorical Variables

# %%
#Categorical Variables also known as object variables.
categorical_variables = [features for features in train.columns if train[features].dtypes == 'O']
categorical_variables
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
train[categorical_variables].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
# Lets find out the number of variables it have in each and every categorical variables 

for feature in categorical_variables:
    print('The feature {} have {} categories'.format(feature,len(train[feature].unique())))
# Out:
# The feature MSZoning have 5 categories
# The feature Street have 2 categories
# The feature Alley have 3 categories
# The feature LotShape have 4 categories
# The feature LandContour have 4 categories
# The feature Utilities have 2 categories
# The feature LotConfig have 5 categories
# The feature LandSlope have 3 categories
# The feature Neighborhood have 25 categories
# The feature Condition1 have 9 categories
# The feature Condition2 have 8 categories
# The feature BldgType have 5 categories
# The feature HouseStyle have 8 categories
# The feature RoofStyle have 6 categories
# The feature RoofMatl have 8 categories
# The feature Exterior1st have 15 categories
# The feature Exterior2nd have 16 categories
# The feature MasVnrType have 5 categories
# The feature ExterQual have 4 categories
# The feature ExterCond have 5 categories
# The feature Foundation have 6 categories
# The feature BsmtQual have 5 categories
# The feature BsmtCond have 5 categories
# ...

# %%
# Find out the relationship between categorical variable and dependent feature SalesPrice
for feature in categorical_variables:
    data=train.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Sale Price')
    plt.title('Relationship between Categorical Variable vs Sale Price')
    plt.show()
